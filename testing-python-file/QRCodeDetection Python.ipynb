# %%
import cv2
import numpy as np
import sys
import time

# %%
inputImage = cv2.imread("G:\\Image Processing @R-Guardian\\stream_scanner_preprocessing\\src\\qr_code\\QR_Code_test.png")

# %%
qrDecoder = cv2.QRCodeDetector()




data = qrDecoder.detectAndDecode(inputImage)

# %%
data
# Out:
# ('This is a test QR code.',
#  array([[[ 12.,  12.],
#          [186.,  12.],
#          [186., 186.],
#          [ 12., 186.]]], dtype=float32),
#  array([[  0,   0,   0,   0,   0,   0,   0, 255, 255,   0, 255, 255,   0,
#          255,   0,   0,   0, 255,   0,   0,   0,   0,   0,   0,   0],
#         [  0, 255, 255, 255, 255, 255,   0, 255, 255, 255,   0,   0,   0,
#            0, 255,   0, 255, 255,   0, 255, 255, 255, 255, 255,   0],
#         [  0, 255,   0,   0,   0, 255,   0, 255,   0,   0,   0, 255,   0,
#          255,   0,   0,   0, 255,   0, 255,   0,   0,   0, 255,   0],
#         [  0, 255,   0,   0,   0, 255,   0, 255, 255,   0,   0,   0, 255,
#          255,   0,   0,   0, 255,   0, 255,   0,   0,   0, 255,   0],
#         [  0, 255,   0,   0,   0, 255,   0, 255, 255, 255,   0, 255, 255,
#          255,   0, 255, 255, 255,   0, 255,   0,   0,   0, 255,   0],
#         [  0, 255, 255, 255, 255, 255,   0, 255, 255,   0, 255, 255, 255,
# ...
