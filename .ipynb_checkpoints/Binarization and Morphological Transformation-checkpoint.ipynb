# %%
path_test= "C:\\Users\\saidu\\OneDrive - The Chinese University of Hong Kong\\Desktop\\STEM EE - Deep Learning @Object Recognition\\For Training\\boat\\7.jpg"

# %%
import cv2 as cv
import sys
img = cv.imread(path_test, 0)
if img is None:
    sys.exit("Could not read the image.")
cv.imshow("Display Window", img)
k = cv.waitKey(100)
# if k == ord("s"):
#     cv.imwrite("starry_night.png", img)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread("testing image\\Sample 1.jpg", 1)

cv.imshow("Sample 1", img)

ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)

# plt.imshow(img)

print(ret, type(thresh1))

# plt.imshow(img)
# Out:
# 127.0 <class 'numpy.ndarray'>

# %%
ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)

titles = ['Original Image','BINARY_INV']
images = [img, thresh1]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
